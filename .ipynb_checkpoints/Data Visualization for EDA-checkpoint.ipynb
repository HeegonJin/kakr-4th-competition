# %%
#invite people for the Kaggle party
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import missingno as msno
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
SEED = 1234

# %%
train = pd.read_csv('./train.csv')
test = pd.read_csv('./test.csv')

# %%
all_data = pd.concat([train, test])

# %% [markdown]
# # Check Missing Values

# %%
all_data.isnull().sum()
# Out:
# id                   0
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education_num        0
# marital_status       0
# occupation           0
# relationship         0
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country       0
# income            6512
# dtype: int64

# %%
msno.matrix(all_data)

# %% [markdown]
# # Feature Overview

# %%
train.columns
# Out:
# Index(['id', 'age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'income'],
#       dtype='object')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26049 entries, 0 to 26048
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              26049 non-null  int64
#  1   age             26049 non-null  int64
#  2   workclass       26049 non-null  object
#  3   fnlwgt          26049 non-null  int64
#  4   education       26049 non-null  object
#  5   education_num   26049 non-null  int64
#  6   marital_status  26049 non-null  object
#  7   occupation      26049 non-null  object
#  8   relationship    26049 non-null  object
#  9   race            26049 non-null  object
#  10  sex             26049 non-null  object
#  11  capital_gain    26049 non-null  int64
#  12  capital_loss    26049 non-null  int64
#  13  hours_per_week  26049 non-null  int64
#  14  native_country  26049 non-null  object
#  15  income          26049 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 3.2+ MB

# %%
train.describe()
# Out:
#                  id           age        fnlwgt  education_num  capital_gain  \
# count  26049.000000  26049.000000  2.604900e+04   26049.000000   26049.00000
# mean   13024.000000     38.569235  1.903045e+05      10.088372    1087.68970
# std     7519.842917     13.671489  1.059663e+05       2.567610    7388.85469
# min        0.000000     17.000000  1.376900e+04       1.000000       0.00000
# 25%     6512.000000     28.000000  1.181080e+05       9.000000       0.00000
# 50%    13024.000000     37.000000  1.788660e+05      10.000000       0.00000
# 75%    19536.000000     48.000000  2.377350e+05      12.000000       0.00000
# max    26048.000000     90.000000  1.484705e+06      16.000000   99999.00000
#
#        capital_loss  hours_per_week
# count  26049.000000    26049.000000
# mean      87.732734       40.443126
# std      403.230205       12.361850
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
train.describe(include='O')
# Out:
#        workclass education      marital_status      occupation relationship  \
# count      26049     26049               26049           26049        26049
# unique         9        16                   7              15            6
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       18123      8433               11970            3304        10541
#
#          race    sex native_country income
# count   26049  26049          26049  26049
# unique      5      2             41      2
# top     White   Male  United-States  <=50K
# freq    22315  17482          23371  19744

# %%
train.sample(5, random_state=SEED)
# Out:
#           id  age  workclass  fnlwgt     education  education_num  \
# 16141  16141   42  Local-gov  100793     Bachelors             13
# 7572    7572   49    Private   44434  Some-college             10
# 3935    3935   22    Private  211361     Bachelors             13
><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >age</th>        <th class="col_heading level0 col2" >fnlwgt</th>        <th class="col_heading level0 col3" >education_num</th>        <th class="col_heading level0 col4" >capital_gain</th>        <th class="col_heading level0 col5" >capital_loss</th>        <th class="col_heading level0 col6" >hours_per_week</th>        <th class="col_heading level0 col7" >income</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_15cf0078_2260_11eb_9628_d45d64abe209level0_row0" class="row_heading level0 row0" >id</th>
#                         <td id="T_15cf0078_2260_11eb_9628_d45d64abe209row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_15cf0078_2260_11eb_9628_d45d64abe209row0_col1" class="data row0 col1" >0.007866</td>
#                         <td id="T_15cf0078_2260_11eb_9628_d45d64abe209row0_col2" class="data row0 col2" >-0.001191</td>
#                         <td id="T_15cf0078_2260_11eb_9628_d45d64abe209row0_col3" class="data row0 col3" >0.002309</td>
#                         <td id="T_15cf0078_2260_11eb_9628_d45d64abe209row0_col4" class="data row0 col4" >0.007228</td>
#                         <td id="T_15cf0078_2260_11eb_9628_d45d64abe209row0_col5" class="data row0 col5" >-0.002553</td>
#                         <td id="T_15cf0078_2260_11eb_9628_d45d64abe209row0_col6" class="data row0 col6" >0.005749</td>
#                         <td id="T_15cf0078_2260_11eb_9628_d45d64abe209row0_col7" class="data row0 col7" >0.004350</td>
#             </tr>
#             <tr>
#                         <th id="T_15cf0078_2260_11eb_9628_d45d64abe209level0_row1" class="row_heading level0 row1" >age</th>
#                         <td id="T_15cf0078_2260_1

# %%
fig, ax = plt.subplots(figsize=(7,7))

mask = np.zeros_like(train.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask, k=1)] = True

sns.heatmap(train.corr(), 
            cmap = 'coolwarm', 
            annot = True,   
            mask=mask,     
            linewidths=.5,  
            cbar_kws={"shrink": .5},
            vmin = -1,vmax = 1  
           )  
plt.show()

# %% [markdown]
# # 0. Income: Target Value

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
train['income'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('income')

sns.countplot('income', data=train, ax=ax[1])
ax[1].set_title('income')
plt.show()

# %% [markdown]
# # 1. ID : Not A Feature &#8594; Drop

# %%
all_data.drop('id', axis=1)
# Out:
#       age     workclass  fnlwgt     education  education_num  \
# 0      40       Private  168538       HS-grad              9
# 1      17       Private  101626           9th              5
# 2      18       Private  353358  Some-college             10
# 3      21       Private  151158  Some-college             10
# 4      24       Private  122234  Some-college             10
# ...   ...           ...     ...           ...            ...
# 6507   35       Private   61343     Bachelors             13
# 6508   41  Self-emp-inc   32185     Bachelors             13
# 6509   39       Private  409189       5th-6th              3
# 6510   35       Private  180342       HS-grad              9
# 6511   28       Private  156819       HS-grad              9
#
#           marital_status         occupation   relationship   race     sex  \
# 0     Married-civ-spouse              Sales        Husband  White    Male
# 1          Never-married  Machine-op-inspct      Own-child  White    Male
# 2          Never-married      Other-service      Own-child  White    Male
# 3          Never-married     Prof-specialty      Own-child  White  Female
# 4          Never-married       Adm-clerical  Not-in-family  Black  Female
# ...                  ...                ...            ...    ...     ...
# 6507  Married-civ-spouse              Sales        Husband  White    Male
# 6508  Married-civ-spouse       Tech-support        Husband  White    Male
# 6509  Married-civ-spouse      Other-service        Husband  White    Male
# 6510  Married-civ-spouse       Craft-repair        Husband  White    Male
# 6511            Divorced  Handlers-cleaners      Unmarried  White  Female
#
#       capital_gain  capital_loss  hours_per_week native_country income
# 0                0             0              60  United-States   >50K
# 1                0             0              20  United-States  <=50K
# 2                0             0              16  United-States  <=50K
# 3                0             0              25  United-States  <=50K
# 4                0             0              20              ?  <=50K
# ...            ...           ...             ...            ...    ...
# 6507             0             0              40  United-States    NaN
# 6508             0             0              40  United-States    NaN
# 6509             0             0              40         Mexico    NaN
# 6510             0             0              40  United-States    NaN
# 6511             0             0              36  United-States    NaN
#
# [32561 rows x 15 columns]

# %% [markdown]
# # 2. Age

# %%
train['age'].describe()
# Out:
# count    26049.000000
# mean        38.569235
# std         13.671489
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         48.000000
# max         90.000000
# Name: age, dtype: float64

# %%
sns.kdeplot(x='age', hue='sex', fill=True, data=train)

# %%
sns.catplot(x="age", y="income",
                data=train, saturation=0.5,
                kind="bar", ci=None, aspect=3)

# %%
f, ax = plt.subplots(1, 2, figsize=(20,10))

x = list(range(15,90,5))

train[train['income']==0].age.plot.hist(ax=ax[0],bins=x, edgecolor='black',color='red')
train[train['income']==1].age.plot.hist(ax=ax[1], bins=x, edgecolor='black', color='green')

ax[0].set_title('income = 0')
ax[1].set_title('income = 1')
ax[0].set_xticks(x)
ax[1].set_xticks(x)
plt.show()

# %%
f,ax=plt.subplots(1,1,figsize=(20,10))
sns.violinplot("sex","age", hue="income", data=train,split=True,ax=ax)
ax.set_title('Sex and Age vs Income')
ax.set_yticks(range(0,100,10))
plt.show()

# %% [markdown]
# # 3. Workclass

# %%
train['workclass'].unique()
# Out:
# array(['Private', 'State-gov', '?', 'Self-emp-not-inc', 'Local-gov',
#        'Federal-gov', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
train['workclass'].value_counts()
# Out:
# Private             18123
# Self-emp-not-inc     2030
# Local-gov            1692
# ?                    1502
# State-gov            1043
# Self-emp-inc          877
# Federal-gov           765
# Without-pay            11
# Never-worked            6
# Name: workclass, dtype: int64

# %%
pd.crosstab(train.workclass, train.income, margins=True).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_1705849a_2260_11eb_905a_d45d64abe209row0_col0{
#             background-color:  #1d8e66;
#             color:  #000000;
#         }#T_1705849a_2260_11eb_905a_d45d64abe209row0_col1{
#             background-color:  #9ece66;
#             color:  #000000;
#         }#T_1705849a_2260_11eb_905a_d45d64abe209row0_col2{
#             background-color:  #6cb666;
#             color:  #000000;
#         }#T_1705849a_2260_11eb_905a_d45d64abe209row0_col3,#T_1705849a_2260_11eb_905a_d45d64abe209row0_col8,#T_1705849a_2260_11eb_905a_d45d64abe209row2_col0,#T_1705849a_2260_11eb_905a_d45d64abe209row2_col1,#T_1705849a_2260_11eb_905a_d45d64abe209row2_col2,#T_1705849a_2260_11eb_905a_d45d64abe209row2_col3,#T_1705849a_2260_11eb_905a_d45d64abe209row2_col4,#T_1705849a_2260_11eb_905a_d45d64abe209row2_col5,#T_1705849a_2260_11eb_905a_d45d64abe209row2_col6,#T_1705849a_2260_11eb_905a_d45d64abe209row2_col7,#T_1705849a_2260_11eb_905a_d45d64abe209row2_col8,#T_1705849a_2260_11eb_905a_d45d64abe209row2_col9{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_1705849a_2260_11eb_905a_d45d64abe209row0_col4{
#             background-color:  #48a366;
#             color:  #000000;
#         }#T_1705849a_2260_11eb_905a_d45d64abe209row0_col5,#T_1705849a_2260_11eb_905a_d45d64abe209row1_col0,#T_1705849a_2260_11eb_905a_d45d64abe209row1_col1,#T_1705849a_2260_11eb_905a_d45d64abe209row1_col2,#T_1705849a_2260_11eb_905a_d45d64abe209row1_col3,#T_1705849a_2260_11eb_905a_d45d64abe209row1_col4,#T_1705849a_2260_11eb_905a_d45d64abe209row1_col6,#T_1705849a_2260_11eb_905a_d45d64abe209row1_col7,#T_1705849a_2260_11eb_905a_d45d64abe209row1_col8,#T_1705849a_2260_11eb_905a_d45d64abe209row1_col9{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_1705849a_2260_11eb_905a_d45d64abe209row0_col6{
#             background-color:  #65b266;
#             color:  #000000;
#         }#T_1705849a_2260_11eb_905a_d45d64abe209row0_col7{
#             background-color:  #62b066;
#             color:  #000000;
#         }#T_1705849a_2260_11eb_905a_d45d64abe209row0_col9{
#             background-color:  #51a866;
#             color:  #000000;
#         }#T_1705849a_2260_11eb_905a_d45d64abe209row1_col5{
#             background-color:  #c4e266;
#             color:  #000000;
#         }</style><table id="T_1705849a_2260_11eb_905a_d45d64abe209" ><thead>    <tr>        <th class="index_name level0" >workclass</th>        <th class="col_heading level0 col0" >?</th>        <th class="col_heading level0 col1" >Federal-gov</th>        <th class="col_heading level0 col2" >Local-gov</th>        <th class="col_heading level0 col3" >Never-worked</th>        <th class="col_heading level0 col4" >Private</th>        <th class="col_heading level0 col5" >Self-emp-inc</th>        <th class="col_heading level0 col6" >Self-emp-not-inc</th>        <th class="col_heading level0 col7" >State-gov</th>        <th class="col_heading level0 col8" >Without-pay</th>        <th class="col_heading level0 col9" >All</th>    </tr>    <tr>        <th class="index_name level0" >income</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1705849a_2260_11eb_905a_d45d64abe209level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row0_col0" class="data row0 col0" >1349</td>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row0_col1" class="data row0 col1" >473</td>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row0_col2" class="data row0 col2" >1187</td>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row0_col3" class="data row0 col3" >6</td>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row0_col4" class="data row0 col4" >14130</td>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row0_col5" class="data row0 col5" >381</td>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row0_col6" class="data row0 col6" >1453</td>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row0_col7" class="data row0 col7" >754</td>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row0_col8" class="data row0 col8" >11</td>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row0_col9" class="data row0 col9" >19744</td>
#             </tr>
#             <tr>
#                         <th id="T_1705849a_2260_11eb_905a_d45d64abe209level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row1_col0" class="data row1 col0" >153</td>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row1_col1" class="data row1 col1" >292</td>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row1_col2" class="data row1 col2" >505</td>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row1_col3" class="data row1 col3" >0</td>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row1_col4" class="data row1 col4" >3993</td>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row1_col5" class="data row1 col5" >496</td>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row1_col6" class="data row1 col6" >577</td>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row1_col7" class="data row1 col7" >289</td>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row1_col8" class="data row1 col8" >0</td>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row1_col9" class="data row1 col9" >6305</td>
#             </tr>
#             <tr>
#                         <th id="T_1705849a_2260_11eb_905a_d45d64abe209level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row2_col0" class="data row2 col0" >1502</td>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row2_col1" class="data row2 col1" >765</td>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row2_col2" class="data row2 col2" >1692</td>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row2_col3" class="data row2 col3" >6</td>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row2_col4" class="data row2 col4" >18123</td>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row2_col5" class="data row2 col5" >877</td>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row2_col6" class="data row2 col6" >2030</td>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row2_col7" class="data row2 col7" >1043</td>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row2_col8" class="data row2 col8" >11</td>
#                         <td id="T_1705849a_2260_11eb_905a_d45d64abe209row2_col9" class="data row2 col9" >26049</td>
#             </tr>
#     </tbody></table>

# %%
train.groupby('workclass')['income'].mean().sort_values().plot(kind='bar', figsize=(10,7))

# %%
sns.catplot(x="sex", y="income", col="workclass",
                data=train, saturation=.5,
                kind="bar", ci=None, aspect=.6)

# %% [markdown]
# # 4. Education Num

# %%
train['education_num'].describe()
# Out:
# count    26049.000000
# mean        10.088372
# std          2.567610
# min          1.000000
# 25%          9.000000
# 50%         10.000000
# 75%         12.000000
# max         16.000000
# Name: education_num, dtype: float64

# %%
pd.crosstab(train.education_num, train.income, margins=True).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T
abe209row1_col6,#T_17998752_2260_11eb_b5d8_d45d64abe209row1_col7,#T_17998752_2260_11eb_b5d8_d45d64abe209row1_col8,#T_17998752_2260_11eb_b5d8_d45d64abe209row1_col9,#T_17998752_2260_11eb_b5d8_d45d64abe209row1_col10,#T_17998752_2260_11eb_b5d8_d45d64abe209row1_col11,#T_17998752_2260_11eb_b5d8_d45d64abe209row1_col12,#T_17998752_2260_11eb_b5d8_d45d64abe209row1_col16{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_17998752_2260_11eb_b5d8_d45d64abe209row0_col16{
#             background-color:  #51a866;
#             color:  #000000;
#         }#T_17998752_2260_11eb_b5d8_d45d64abe209row1_col13{
#             background-color:  #c7e366;
#             color:  #000000;
#         }#T_17998752_2260_11eb_b5d8_d45d64abe209row1_col14,#T_17998752_2260_11eb_b5d8_d45d64abe209row1_col15{
#             background-color:  #5cae66;
#             color:  #000000;
#         }</style><table id="T_17998752_2260_11eb_b5d8_d45d64abe209" ><thead>    <tr>        <th class="index_name level0" >education_num</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >4</th>        <th class="col_heading level0 col4" >5</th>        <th class="col_heading level0 col5" >6</th>        <th class="col_heading level0 col6" >7</th>        <th class="col_heading level0 col7" >8</th>        <th class="col_heading level0 col8" >9</th>        <th class="col_heading level0 col9" >10</th>        <th class="col_heading level0 col10" >11</th>        <th class="col_heading level0 col11" >12</th>        <th class="col_heading level0 col12" >13</th>        <th class="col_heading level0 col13" >14</th>        <th class="col_heading level0 col14" >15</th>        <th class="col_heading level0 col15" >16</th>        <th class="col_heading level0 col16" >All</th>    </tr>    <tr>        <th class="index_name level0" >income</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_17998752_2260_11eb_b5d8_d45d64abe209level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_17998752_2260_11eb_b5d8_d45d64abe209row0_col0" class="data row0 col0" >40</td>
#                         <td id="T_17998752_2260_11eb_b5d8_d45d64abe209row0_col1" class="data row0 col1" >129</td>
#                         <td id="T_17998752_2260_11eb_b5d8_d45d64abe209row0_col2" class="data row0 col2" >252</td>
#                         <td id="T_17998752_2260_11eb_b5d8_d45d64abe209row0_col3" class="data row0 col3" >476</td>
#                         <td id="T_17998752_2260_11eb_b5d8_d45d64abe209row0_col4" class="data row0 col4" >396</td>
#                         <td id="T_17998752_2260_11eb_b5d8_d45d64abe209row0_col5" class="data row0 col5" >678</td>
#                         <td id="T_17998752_2260_11eb_b5d8_d45d64abe209row0_col6" class="data row0 col6" >867</td>
#                         <td id="T_17998752_2260_11eb_b5d8_d45d64abe209row0_col7" class="data row0 col7" >333</td>
#                         <td id="T_17998752_2260_11eb_b5d8_d45d64abe209row0_col8" class="data row0 col8" >7096</td>
#                         <td id="T_17998752_2260_11eb_b5d8_d45d64abe209row0_col9" class="data row0 col9" >4683</td>
#                         <td id="T_17998752_2260_11eb_b5d8_d45d64abe209row0_col10" class="data row0 col10" >816</td>
#                         <td id="T_17998752_2260_11eb_b5d8_d45d64abe209row0_col11" class="data row0 col11" >627</td>
#                         <td id="T_17998752_2260_11eb_b5d8_d45d64abe209row0_col12" class="data row0 col12" >2539</td>
#                         <td id="T_17998752_2260_11eb_b5d8_d45d64abe209row0_col13" class="data row0 col13" >604</td>
#                         <td id="T_17998752_2260_11eb_b5d8_d45d64abe209row0_col14" class="data row0 col14" >124</td>
#                         <td id="T_17998752_2260_11eb_b5d8_d45d64abe209row0_col15" class="data row0 col15" >84</td>
#                         <td id="T_17998752_2260_11eb_b5d8_d45d64abe209row0_col16" class="data row0 col16" >19744</td>
#             </tr>
#             <tr>
#                         <th id="T_17998752_2260_11eb_b5d8_d45d64abe209level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_17998752_2260_11eb_b5d8_d45d64abe209row1_col0" class="data row1 col0" >0</td>
#                         <td id="T_17998752_2260_11eb_b5d8_d45d64abe209row1_col1" class="data row1 col1" >5</td>
#                         <td id="T_17998752_2260_11eb_b5d8_

# %%
sns.catplot(x="education_num", y="income", col="sex",
                data=train, saturation=.5,
                kind="bar", ci=None, aspect=1)

# %%
fig, ax = plt.subplots(1,1, figsize= (12, 5))
sns.countplot(data=train, x='race', ax = ax, hue='education')
plt.show()

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
train['education_num'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'], ax=ax[0])
ax[0].set_title('Number Of People by Education Level')
ax[0].set_ylabel('Count')
sns.countplot('education_num', hue='income', data=train, ax=ax[1])
ax[1].set_title('Education: >50K(1) or <=50K(0)')
plt.show()

# %% [markdown]
# # 5. Capital gain & loss

# %%
train['capital_gain'].describe()
# Out:
# count    26049.00000
# mean      1087.68970
# std       7388.85469
# min          0.00000
# 25%          0.00000
# 50%          0.00000
# 75%          0.00000
# max      99999.00000
# Name: capital_gain, dtype: float64

# %%
f, ax = plt.subplots(1,2,figsize=(18, 8))
sns.histplot(train.loc[ (train['capital_gain'] > 0) & (train['income'] == 0), 'capital_gain'], kde=True, ax=ax[0])
sns.histplot(train.loc[ (train['capital_gain'] > 0) & (train['income'] == 1), 'capital_gain'], kde=True, ax=ax[1])
ax[0].set_title('income=0')
ax[1].set_title('income=1')
# Out:
# Text(0.5,1,'income=1')

# %%
f, ax = plt.subplots(1,2,figsize=(18, 8))
sns.histplot(train.loc[ (train['capital_loss'] > 0) & (train['income'] == 0), 'capital_loss'], kde=True, ax=ax[0])
sns.histplot(train.loc[ (train['capital_loss'] > 0) & (train['income'] == 1), 'capital_loss'], kde=True, ax=ax[1])
ax[0].set_title('income=0')
ax[1].set_title('income=1')
# Out:
# Text(0.5,1,'income=1')

# %%
train['capital_net'] = train['capital_gain'] - train['capital_loss']

# %%
train[train['capital_net'] == 0].count()
# Out:
# id                22630
# age               22630
# workclass         22630
# fnlwgt            22630
# education         22630
# education_num     22630
# marital_status    22630
# occupation        22630
# relationship      22630
# race              22630
# sex               22630
# capital_gain      22630
# capital_loss      22630
# hours_per_week    22630
# native_country    22630
# income            22630
# capital_net       22630
# dtype: int64

# %%
train.loc[(train['income'] == 0), 'capital_net'].describe()
# Out:
# count    19744.00000
# mean        94.02345
# std        995.73002
# min      -4356.00000
# 25%          0.00000
# 50%          0.00000
# 75%          0.00000
# max      41310.00000
# Name: capital_net, dtype: float64

# %%
train.loc[(train['income'] == 1), 'capital_net'].describe()
# Out:
# count     6305.000000
# mean      3836.872324
# std      14605.534943
# min      -3683.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      99999.000000
# Name: capital_net, dtype: float64

# %%
f, ax = plt.subplots(1,2,figsize=(18, 8))
sns.histplot(train.loc[(train['income'] == 0), 'capital_net'], kde=True, ax=ax[0])
sns.histplot(train.loc[(train['income'] == 1), 'capital_net'], kde=True, ax=ax[1])
ax[0].set_title('income=0')
ax[1].set_title('income=1')
# Out:
# Text(0.5,1,'income=1')

# %%
train.loc[(train['income'] == 1) & (train['capital_net'] > 0), 'capital_net'].quantile(0.1)
# Out:
# 4787.0

# %%
train.loc[(train['income'] == 0) & (train['capital_net'] > 0), 'capital_net'].quantile(0.9)
# Out:
# 5013.0

# %% [markdown]
# # 6. Hours per week

# %%
train['hours_per_week'].describe()
# Out:
# count    26049.000000
# mean        40.443126
# std         12.361850
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000
# Name: hours_per_week, dtype: float64

# %%
sns.catplot(x="hours_per_week", y="income", row="sex",
                data=train, saturation=.5,
                kind="bar", ci=None, aspect=4)

# %%
f, ax = plt.subplots(1, 2, figsize=(20,10))

x = list(range(0,100,5))

train[train['income']==0].hours_per_week.plot.hist(ax=ax[0],bins=x, edgecolor='black',color='red')
train[train['income']==1].hours_per_week.plot.hist(ax=ax[1], bins=x, edgecolor='black', color='green')

ax[0].set_title('income = 0')
ax[1].set_title('income = 1')
ax[0].set_xticks(x)
ax[1].set_xticks(x)
plt.show()

# %%
f, ax = plt.subplots(1,2,figsize=(18, 8))
sns.histplot(train.loc[(train['income'] == 0), 'hours_per_week'], kde=True, ax=ax[0])
sns.histplot(train.loc[(train['income'] == 1), 'hours_per_week'], kde=True, ax=ax[1])

# %% [markdown]
# # 7. Marital Status & Relationship

# %%
sns.factorplot('education_num', 'income', col='marital_status', data=train)
plt.show()

# %%
sns.factorplot('relationship', 'income', data=train)
fig=plt.gcf()
fig.set_size_inches(20,6)
plt.show()

# %%
sns.factorplot('marital_status', 'income', data=train)
fig=plt.gcf()
fig.set_size_inches(20,6)
plt.show()

# %% [markdown]
# # 8. Occupation

# %%
f,ax=plt.subplots(2,2,figsize=(50,15))
sns.countplot('occupation',data=train,ax=ax[0,0])
ax[0,0].set_title('No. Of People occupation')
sns.countplot('occupation',hue='sex',data=train,ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for occupation')
sns.countplot('occupation',hue='income',data=train,ax=ax[1,0])
ax[1,0].set_title('occupation vs income')
sns.countplot('occupation',hue='education_num',data=train,ax=ax[1,1])
ax[1,1].set_title('occupation vs education_num')
f.tight_layout()
#plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()

# %%
sns.factorplot('occupation','income',data=train)
fig=plt.gcf()
fig.set_size_inches(30,6)
plt.show()

# %% [markdown]
# # 9. Sex

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
train[['sex', 'income']].groupby(['sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title("Income vs Sex")
sns.countplot('sex', hue='income', data=train, ax=ax[1])
ax[1].set_title("Sex: >50K(1) or <=50K(0)")
plt.show()

# %% [markdown]
# # 10. Race

# %%
train['race'].value_counts()
# Out:
# White                 22315
# Black                  2476
# Asian-Pac-Islander      800
# Amer-Indian-Eskimo      254
# Other                   204
# Name: race, dtype: int64

# %%
sns.factorplot('race', 'income', data=train)
fig=plt.gcf()
fig.set_size_inches(20,6)
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize= (12,5))
sns.boxplot(data=train, x='race', y='age', ax = ax, hue = 'sex')

#sns.violinplot(data=train_df, x='race', y='age', ax = ax, hue = 'sex')

# %%
f, ax = plt.subplots(1,2,figsize=(18, 8))
sns.histplot(train.loc[(train['race'] == 'White'), 'income'], kde=True, ax=ax[0])
sns.histplot(train.loc[(train['race'] != 'White'), 'income'], kde=True, ax=ax[1])
ax[0].set_title('White')
ax[1].set_title('Not White')
# Out:
# Text(0.5,1,'Not White')

# %% [markdown]
# # 11. Native Country

# %%
train['native_country'].value_counts()
# Out:
# United-States                 23371
# Mexico                          534
# ?                               456
# Philippines                     163
# Germany                         101
# Puerto-Rico                      95
# Canada                           92
# El-Salvador                      79
# India                            77
# Cuba                             76
# England                          67
# Jamaica                          64
# South                            63
# China                            57
# Columbia                         52
# Guatemala                        52
# Italy                            50
# Vietnam                          50
# Dominican-Republic               48
# Japan                            47
# Poland                           47
# Taiwan                           39
# Iran                             35
# Haiti                            35
# Portugal                         30
# Nicaragua                        28
# Peru                             26
# Greece                           24
# France                           24
# Ecuador                          24
# Ireland                          18
# Laos                             15
# Cambodia                         14
# Trinadad&Tobago                  14
# Hong                             14
# Outlying-US(Guam-USVI-etc)       13
# Thailand                         13
# Yugoslavia                       12
# Honduras                         11
# Hungary                          11
# Scotland                          8
# Name: native_country, dtype: int64

# %%
train[['native_country', 'income']].groupby('native_country')['income'].mean().sort_values()
# Out:
# native_country
# Outlying-US(Guam-USVI-etc)    0.000000
# Honduras                      0.000000
# Columbia                      0.038462
# Dominican-Republic            0.041667
# Mexico                        0.048689
# Guatemala                     0.057692
# Portugal                      0.066667
# Trinadad&Tobago               0.071429
# Nicaragua                     0.071429
# Peru                          0.076923
# Vietnam                       0.080000
# El-Salvador                   0.088608
# Jamaica                       0.109375
# Haiti                         0.114286
# Puerto-Rico                   0.115789
# Laos                          0.133333
# Thailand                      0.153846
# Ecuador                       0.166667
# Poland                        0.212766
# South                         0.222222
# Ireland                       0.222222
# China                         0.228070
# ?                             0.234649
# United-States                 0.247315
# Greece                        0.250000
# Scotland                      0.250000
# Cuba                          0.263158
# Hungary                       0.272727
# Hong                          0.285714
# Philippines                   0.300613
# Canada                        0.315217
# England                       0.343284
# Germany                       0.346535
# Italy                         0.380000
# India                         0.402597
# Japan                         0.404255
# France                        0.416667
# Yugoslavia                    0.416667
# Cambodia                      0.428571
# Taiwan                        0.461538
# Iran                          0.485714
# Name: income, dtype: float64

# %%
sns.factorplot('native_country', 'income', data=train)
fig=plt.gcf()
fig.set_size_inches(70,10)
plt.show()

# %% [markdown]
# sample 갯수가 작아서 전반적으로 variance가 크다.
